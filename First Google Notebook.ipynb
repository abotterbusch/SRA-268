# %% [markdown]
# ### Weather Data

# %% [markdown]
# ### The data that I analyzed was the total amount of percipitation in the spring months from 2017 to 2019. I looked at this information in order to see which spring month over the three years would have the most percipitation.

# %% [markdown]
# ### ![alt text](https://drive.google.com/uc?id=1Jp33mFzaa0tJ8mU5uGR9wjloXOWIbqn0)

# %% [markdown]
# ### Conclusion: This graph has made it easy to see that the later months of spring have consistantly recieved more percipitation throughout the past three years than the earlier months.
